# %%
print("Hello World!")

# %%
# %sql
SELECT "Hello World from Databricks SQL!"

# %%
# %run ../Includes/Setup

# %%
print(full_name)

# %%
full_name

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files=dbutils.fs.ls('/databricks-datasets/')
print(files)

# %%
display(files)
