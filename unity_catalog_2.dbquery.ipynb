-- %%
grant select on table demoworkspace.hr_db.employees to `account users`;

grant use schema on schema demoworkspace.hr_db to `account users`;
grant use catalog on catalog demoworkspace to `account users`;

show grants on table demoworkspace.hr_db.employees;
show grants on schema demoworkspace.hr_db;
show grants on catalog demoworkspace;
